# %% [markdown]
# # Homework
# https://github.com/DataTalksClub/llm-zoomcamp/blob/main/cohorts/2024/05-orchestration/homework.md

# %% [markdown]
# ## Prepare images

# %%
# !git clone https://github.com/mage-ai/rag-project

# %% [markdown]
# Add `python-docx` and `elasticsearch` into *requirements.txt* (under *rag-project/llm/*)

# %% [markdown]
# Pull mage image

# %%
# !docker pull mageai/mageai:llm

# %% [markdown]
# Start Docker compose

# %%
./scripts/start.sh

# %% [markdown]
# Info about containers:

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                                                 COMMAND                  CREATED          STATUS         PORTS                                                                                  NAMES
# cd19c22ab4cf   rag-project-magic-platform                            "/app/run_app.sh mag…"   43 minutes ago   Up 8 minutes   0.0.0.0:6789->6789/tcp, :::6789->6789/tcp, 7789/tcp                                    rag-project-magic-platform-1
# 54ef02c64e8b   docker.elastic.co/elasticsearch/elasticsearch:8.5.0   "/bin/tini -- /usr/l…"   43 minutes ago   Up 8 minutes   0.0.0.0:9200->9200/tcp, :::9200->9200/tcp, 0.0.0.0:9300->9300/tcp, :::9300->9300/tcp   rag-project-elasticsearch-1
# da8bceae7b36   pgvector/pgvector:0.6.0-pg16                          "docker-entrypoint.s…"   43 minutes ago   Up 8 minutes   0.0.0.0:5432->5432/tcp, :::5432->5432/tcp                                              rag-project-magic-database-1

# %% [markdown]
# Mage is running on http://localhost:6789/

# %% [markdown]
# ## Q1. Running Mage
# Version: **v0.9.72**

# %% [markdown]
# ![image.png](attachment:f1e5bdba-60f6-4dfd-9ac0-2f6feb8c9273.png)

# %% [markdown]
# ## Creating a RAG pipeline
# ## Q2. Reading the documents

# %% [markdown]
# https://youtu.be/9BJppvgLINc?list=PL3MmuxUbc_hIB4fSqLy_0AfTjVLpgjV3R \
# \<New pipeline\> -> "Retrieval Augmented Generation" -> **Load** stage (\<Go\>) -> **Ingest** (\<Go\>) -> \<Add block\> -> \<Custom code\>

# %% [markdown]
# Add code from: https://github.com/DataTalksClub/llm-zoomcamp/blob/main/cohorts/2024/05-orchestration/parse-faq-llm.ipynb

# %% [markdown]
# ![image.png](attachment:4f4f0f55-827c-4620-8db5-68f3e4ebaf68.png)

# %% [markdown]
# ## Q3. Chunking

# %% [markdown]
# Data preparation -> Transform -> Chunking -> \<Add block\> -> Custom code \
# Code from: https://github.com/DataTalksClub/llm-zoomcamp/blob/main/cohorts/2024/05-orchestration/homework.md#q3-chunking

# %% [markdown]
# ![image.png](attachment:c3f6474c-aa2b-4c12-842c-f9448bb38e34.png)

# %% [markdown]
# ## Tokenization and embeddings
# https://github.com/DataTalksClub/llm-zoomcamp/blob/main/cohorts/2024/05-orchestration/homework.md#tokenization-and-embeddings

# %% [markdown]
# Data preparation -> Transform -> Tokenization -> \<Add block\> -> Custom code -> No changes in the code -> \<Run\> \
# Data preparation -> Transform -> Embed -> \<Add block\> -> Custom code -> No changes in the code -> \<Run\>

# %% [markdown]
# ## Q4. Export

# %%
# !curl http://localhost:9200
# Out:
# {
#   "name" : "54ef02c64e8b",
#   "cluster_name" : "docker-cluster",
#   "cluster_uuid" : "rJL4o_LUQ9ObXSj2IKANOA",
#   "version" : {
#     "number" : "8.5.0",
#     "build_flavor" : "default",
#     "build_type" : "docker",
#     "build_hash" : "c94b4700cda13820dad5aa74fae6db185ca5c304",
#     "build_date" : "2022-10-24T16:54:16.433628434Z",
#     "build_snapshot" : false,
#     "lucene_version" : "9.4.1",
#     "minimum_wire_compatibility_version" : "7.17.0",
#     "minimum_index_compatibility_version" : "7.0.0"
#   },
#   "tagline" : "You Know, for Search"
# }

# %% [markdown]
# Data preparation -> Export -> Vector database -> \<Add block\> -> Elasticsearch -> \<Edit\>

# %% [markdown]
# ![image.png](attachment:354eed6d-e64c-4eea-8fa5-c23e9d9e81e9.png)

# %% [markdown]
# document id = "a976d6e7"

# %% [markdown]
# ## Q5. Testing the retrieval

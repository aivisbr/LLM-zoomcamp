# %% [markdown]
# # dlt intro
# * https://www.youtube.com/watch?v=qUNyfR_X2Mo
# * https://github.com/DataTalksClub/llm-zoomcamp/blob/main/cohorts/2024/workshops/dlt.md
# * https://colab.research.google.com/drive/1nNOybHdWQiwUUuJFZu__xvJxL_ADU3xl?usp=sharing#scrollTo=zpqhOpmrS45-

# %%
# !pip install dlt[lancedb]==0.5.1a0
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: dlt==0.5.1a0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt[lancedb]==0.5.1a0) (0.5.1a0)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/codespace/.local/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (6.0.1)
# Requirement already satisfied: astunparse>=1.6.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (1.6.3)
# Requirement already satisfied: click>=7.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (8.1.7)
# Requirement already satisfied: fsspec>=2022.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (2024.6.1)
# Requirement already satisfied: gitpython>=3.1.29 in /home/codespace/.local/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (3.1.43)
# Requirement already satisfied: giturlparse>=0.10.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (0.12.0)
# Requirement already satisfied: hexbytes>=0.2.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (1.2.1)
# Requirement already satisfied: humanize>=4.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (4.10.0)
# Requirement already satisfied: jsonpath-ng>=1.5.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (1.6.1)
# Requirement already satisfied: makefun>=1.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (1.15.4)
# Requirement already satisfied: orjson<=3.9.10,>=3.6.7 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (3.9.10)
# Requirement already satisfied: packaging>=21.1 in /home/codespace/.local/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (24.1)
# Requirement already satisfied: pathvalidate>=2.5.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (3.2.0)
# Requirement already satisfied: pendulum>=2.1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (3.0.0)
# Requirement already satisfied: pytz>=2022.6 in /home/codespace/.local/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (2024.1)
# Requirement already satisfied: requests>=2.26.0 in /home/codespace/.local/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (2.32.3)
# Requirement already satisfied: requirements-parser>=0.5.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (0.9.0)
# Requirement already satisfied: semver>=2.13.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (3.0.2)
# Requirement already satisfied: setuptools>=65.6.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (68.2.2)
# Requirement already satisfied: simplejson>=3.17.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (3.19.2)
# Requirement already satisfied: tenacity>=8.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (8.5.0)
# Requirement already satisfied: tomlkit>=0.11.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (0.13.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (4.12.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (2024.1)
# Requirement already satisfied: lancedb>=0.8.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt[lancedb]==0.5.1a0) (0.10.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dlt[lancedb]==0.5.1a0) (15.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from astunparse>=1.6.3->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (0.43.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /home/codespace/.local/lib/python3.10/site-packages (from astunparse>=1.6.3->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitpython>=3.1.29->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (4.0.11)
# Requirement already satisfied: ply in /usr/local/python/3.10.13/lib/python3.10/site-packages (from jsonpath-ng>=1.5.3->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (3.11)
# Requirement already satisfied: deprecation in /usr/local/python/3.10.13/lib/python3.10/site-packages (from lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (2.1.0)
# Requirement already satisfied: pylance==0.14.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (0.14.1)
# Requirement already satisfied: ratelimiter~=1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (0.9.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (4.66.4)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (2.8.2)
# Requirement already satisfied: attrs>=21.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (23.2.0)
# Requirement already satisfied: cachetools in /usr/local/python/3.10.13/lib/python3.10/site-packages (from lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (5.4.0)
# Requirement already satisfied: overrides>=0.7 in /home/codespace/.local/lib/python3.10/site-packages (from lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (7.7.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pylance==0.14.1->lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.6 in /home/codespace/.local/lib/python3.10/site-packages (from pendulum>=2.1.2->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (2.9.0.post0)
# Requirement already satisfied: time-machine>=2.6.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pendulum>=2.1.2->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (2.14.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.26.0->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.26.0->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests>=2.26.0->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.26.0->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (2024.7.4)
# Requirement already satisfied: types-setuptools>=69.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requirements-parser>=0.5.0->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (71.0.0.20240722)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt==0.5.1a0->dlt[lancedb]==0.5.1a0) (5.0.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic>=1.10->lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic>=1.10->lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (2.20.1)
# Requirement already satisfied: decorator>=3.4.2 in /home/codespace/.local/lib/python3.10/site-packages (from retry>=0.9.2->lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from retry>=0.9.2->lancedb>=0.8.2->dlt[lancedb]==0.5.1a0) (1.11.0)
# Requirement already satisfied: sentence-transformers in /usr/local/python/3.10.13/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (4.42.4)
# Requirement already satisfied: tqdm in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /home/codespace/.local/lib/python3.10/site-packages (from sentence-transformers) (2.3.1+cpu)
# Requirement already satisfied: numpy in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.10/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from sentence-transformers) (1.14.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (0.24.0)
# Requirement already satisfied: Pillow in /home/codespace/.local/lib/python3.10/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.0)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)

# %% [markdown]
# ## Load the data

# %%
import requests
import dlt

qa_dataset = requests.get("https://github.com/DataTalksClub/llm-zoomcamp/blob/main/01-intro/documents.json?raw=1").json()

@dlt.resource
def qa_documents():
  for course in qa_dataset:
    yield course["documents"]

pipeline = dlt.pipeline(pipeline_name="from_json", destination="lancedb", dataset_name="qanda")

load_info = pipeline.run(qa_documents, table_name="documents")

print(load_info)
# Out:
# Pipeline from_json load step completed in 0.20 seconds
# 1 load package(s) were loaded to destination LanceDB and into dataset qanda
# The LanceDB destination used <dlt.destinations.impl.lancedb.configuration.LanceDBCredentials object at 0x7a7fb27b57e0> location to store data
# Load package 1721688122.5950298 is LOADED and contains no failed jobs

# %%
import lancedb

db = lancedb.connect("./.lancedb")
print(db.table_names())
# Out:
# ['qanda____dlt_loads', 'qanda____dlt_pipeline_state', 'qanda____dlt_version', 'qanda___dltSentinelTable', 'qanda___documents']

# %%
db_table = db.open_table("qanda___documents")

db_table.to_pandas()
# Out:
#                                       id__  \
# 0     c5ac6328-cbef-5a1a-bc6e-5ca60fcc9bc1
# 1     f448f149-dbd5-563d-b4df-c28bdfa00b5a
# 2     af4f0c30-3e7d-5d53-9b73-8c1e6bdf2db9
# 3     66cdb898-4be1-579c-b734-927de4c7ccd7
# 4     76c79b57-185b-535a-b991-98cfdd4c3825
# ...                                    ...
# 1891  c34e8121-17db-5559-9dac-d7b707bab76e
# 1892  b3e4e993-a174-5354-968a-a4026399249f
# 1893  21533d64-c3cd-5471-807c-ae3629d0f7d8
# 1894  38c94f86-5595-59ff-9965-27aa63d832f2
# 1895  0ee1c82a-606b-5924-810c-48285da19707
#
#                                                    text  \
# 0     The purpose of this document is to capture fre...
# 1     GitHub - DataTalksClub data-engineering-zoomca...
# 2     Yes, even if you don't register, you're still ...
# 3     You don't need it. You're accepted. You can al...
# 4     You can start by installing and setting up all...
# ...                                                 ...
# 1891  Problem description\nThis is the step in the c...
# 1892  Problem description\nWhen a docker-compose fil...
# 1893  Problem description\nIf you are having problem...
# 1894  Problem description\nPre-commit command was fa...
# 1895  Problem description\nInfrastructure created in...
#
#                                section  \
# 0     General course-related questions
# 1     General course-related questions
# 2     General course-related questions
# 3     General course-related questions
# 4     General course-related questions
# ...                                ...
# 1891          Module 6: Best practices
# 1892          Module 6: Best practices
# 1893          Module 6: Best practices
# 1894          Module 6: Best practices
# 1895          Module 6: Best practices
#
#                                                question        _dlt_load_id  \
# 0                  Course - When will the course start?  1721688099.8029122
# 1     Course - What are the prerequisites for this c...  1721688099.8029122
# 2     Course - Can I still join the course after the...  1721688099.8029122
# 3     Course - I have registered for the Data Engine...  1721688099.8029122
# 4      Course - What can I do before the course starts?  1721688099.8029122
# ...                                                 ...                 ...
# 1891  Github actions: Permission denied error when e...  1721688122.5950298
# 1892  Managing Multiple Docker Containers with docke...  1721688122.5950298
# 1893           AWS regions need to match docker-compose  1721688122.5950298
# 1894                                   Isort Pre-commit  1721688122.5950298
# 1895  How to destroy infrastructure created via GitH...  1721688122.5950298
#
#              _dlt_id
# 0     SyPl51ibXJQ0xA
# 1     pKLtkrg3kGLLcQ
# 2     SHuTmrP6CWGweQ
# 3     TT5vTEvEWTSYaA
# 4     2O1UdqLyV5RA9w
# ...              ...
# 1891  YzqgScGlGbaVKQ
# 1892  yez11sIWlexC+A
# 1893  TO1g25i7I787NA
# 1894  28xUs7iSUl1eRQ
# 1895  V/yriyx7dOyLRg
#
# [1896 rows x 6 columns]

# %% [markdown]
# ## Load and embed the data

# %%
import os
from dlt.destinations.adapters import lancedb_adapter

os.environ["DESTINATION__LANCEDB__EMBEDDING_MODEL_PROVIDER"] = "sentence-transformers"
os.environ["DESTINATION__LANCEDB__EMBEDDING_MODEL"] = "all-MiniLM-L6-v2"

pipeline = dlt.pipeline(pipeline_name="from_json_embedded", destination="lancedb", dataset_name="qanda_embedded")

load_info = pipeline.run(lancedb_adapter(qa_documents, embed=["text", "question"]), table_name="documents")
print(load_info)
# Out:
# _dlt_version
# [{'name': 'version', 'data_type': 'bigint', 'nullable': False}, {'name': 'engine_version', 'data_type': 'bigint', 'nullable': False}, {'name': 'inserted_at', 'data_type': 'timestamp', 'nullable': False}, {'name': 'schema_name', 'data_type': 'text', 'nullable': False}, {'name': 'version_hash', 'data_type': 'text', 'nullable': False}, {'name': 'schema', 'data_type': 'text', 'nullable': False}]
# _dlt_pipeline_state
# [{'name': 'version', 'data_type': 'bigint', 'nullable': False}, {'name': 'engine_version', 'data_type': 'bigint', 'nullable': False}, {'name': 'pipeline_name', 'data_type': 'text', 'nullable': False}, {'name': 'state', 'data_type': 'text', 'nullable': False}, {'name': 'created_at', 'data_type': 'timestamp', 'nullable': False}, {'name': 'version_hash', 'data_type': 'text', 'nullable': True}, {'name': '_dlt_load_id', 'data_type': 'text', 'nullable': False}, {'name': '_dlt_id', 'data_type': 'text', 'nullable': False, 'unique': True}]
# documents
# [{'name': 'text', 'x-lancedb-embed': True, 'data_type': 'text', 'nullable': True}, {'name': 'section', 'data_type': 'text', 'nullable': True}, {'name': 'question', 'x-lancedb-embed': True, 'data_type': 'text', 'nullable': True}, {'name': '_dlt_load_id', 'data_type': 'text', 'nullable': False}, {'name': '_dlt_id', 'data_type': 'text', 'nullable': False, 'unique': True}]
# _dlt_loads
# [{'name': 'load_id', 'data_type': 'text', 'nullable': False}, {'name': 'schema_name', 'data_type': 'text', 'nullable': True}, {'name': 'status', 'data_type': 'bigint', 'nullable': False}, {'name': 'inserted_at', 'data_type': 'timestamp', 'nullable': False}, {'name': 'schema_version_hash', 'data_type': 'text', 'nullable': True}]
# UPLOAD
# Pipeline from_json_embedded load step completed in 21.55 seconds
# 1 load package(s) were loaded to destination LanceDB and into dataset qanda_embedded
# The LanceDB destination used <dlt.destinations.impl.lancedb.configuration.LanceDBCredentials object at 0x7a7fb27dd2a0> location to store data
# Load package 1721688305.6704516 is LOADED and contains no failed jobs

# %%
db = lancedb.connect("./.lancedb")
print(db.table_names())
# Out:
# ['qanda____dlt_loads', 'qanda____dlt_pipeline_state', 'qanda____dlt_version', 'qanda___dltSentinelTable', 'qanda___documents', 'qanda_embedded____dlt_loads', 'qanda_embedded____dlt_pipeline_state', 'qanda_embedded____dlt_version', 'qanda_embedded___dltSentinelTable', 'qanda_embedded___documents']

# %%
db_table = db.open_table("qanda_embedded___documents")

db_table.to_pandas()
# Out:
#                                      id__  \
# 0    90198cdb-5e95-5339-b74b-dfd95343a57a
# 1    8872b4e6-47d3-5de8-bcae-bb509a7aa3d6
# 2    9a31d951-ce7c-5afe-b0ac-5bb7b2896a7a
# 3    c4aeb12c-ca89-55a0-a140-93640eece786
# 4    f4952fb8-cbf3-5a31-83f7-9f503a1a83f8
# ..                                    ...
# 943  8b9b7cca-b73f-5d62-9339-68d5c86fe527
# 944  a11b64e1-d6eb-565d-869e-e651a642c688
# 945  2b83dd74-4a3c-5d48-8c4f-09f90573c9df
# 946  1c902ca1-43d2-57da-82ac-df9d93c6ae8d
# 947  14868aa4-a4d3-5df9-9251-7648c1f4968f
#
#                                               vector__  \
# 0    [-0.00035094196, -0.062014297, -0.037999876, 0...
# 1    [0.020011412, -0.011535538, 0.013017209, -0.00...
# 2    [0.014857555, -0.06664993, -0.013571247, 0.023...
# 3    [-0.023312032, -0.09461493, 0.056361612, -0.00...
# 4    [0.026537651, -0.01779666, 0.0021155947, 0.006...
# ..                                                 ...
# 943  [0.016619362, -0.033603165, -0.093347155, -0.0...
# 944  [0.026872855, -0.0019949432, 0.008369081, -0.0...
# 945  [0.03513756, 0.056265566, 0.024428478, -0.0651...
# 946  [0.03380979, -0.0031218985, 0.0017484669, 0.01...
# 947  [-0.00075231574, 0.0042315223, 0.0025023425, -...
#
#                                                   text  \
# 0    The purpose of this document is to capture fre...
# 1    GitHub - DataTalksClub data-engineering-zoomca...
# 2    Yes, even if you don't register, you're still ...
# 3    You don't need it. You're accepted. You can al...
# 4    You can start by installing and setting up all...
# ..                                                 ...
# 943  Problem description\nThis is the step in the c...
# 944  Problem description\nWhen a docker-compose fil...
# 945  Problem description\nIf you are having problem...
# 946  Problem description\nPre-commit command was fa...
# 947  Problem description\nInfrastructure created in...
#
#                               section  \
# 0    General course-related questions
# 1    General course-related questions
# 2    General course-related questions
# 3    General course-related questions
# 4    General course-related questions
# ..                                ...
# 943          Module 6: Best practices
# 944          Module 6: Best practices
# 945          Module 6: Best practices
# 946          Module 6: Best practices
# 947          Module 6: Best practices
#
#                                               question        _dlt_load_id  \
# 0                 Course - When will the course start?  1721688305.6704516
# 1    Course - What are the prerequisites for this c...  1721688305.6704516
# 2    Course - Can I still join the course after the...  1721688305.6704516
# 3    Course - I have registered for the Data Engine...  1721688305.6704516
# 4     Course - What can I do before the course starts?  1721688305.6704516
# ..                                                 ...                 ...
# 943  Github actions: Permission denied error when e...  1721688305.6704516
# 944  Managing Multiple Docker Containers with docke...  1721688305.6704516
# 945           AWS regions need to match docker-compose  1721688305.6704516
# 946                                   Isort Pre-commit  1721688305.6704516
# 947  How to destroy infrastructure created via GitH...  1721688305.6704516
#
#             _dlt_id
# 0    iHWVYitCyZixkw
# 1    YtCjWP1N+Ivvqw
# 2    bZPvrFH9YbNfrA
# 3    dGhGtURk56shyw
# 4    3hKa4rmgtHL1DQ
# ..              ...
# 943  Ua4+6iX8o26zXg
# 944  BIb9tu4DYMxE/A
# 945  VuWw3XwJk5k+tw
# 946  uN5suEZSlIXgjg
# 947  PuNNSAeQBo6Cig
#
# [948 rows x 7 columns]
